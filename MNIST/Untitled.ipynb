# %%
#loading database
from torchvision import datasets
import os
import numpy as np

# %%
root_directory = os.path.join(os.getcwd(),'Dataset')

# %%
train_data = datasets.MNIST(root_directory, train=False,download=True)

# %%
x_train = np.array(list(map(lambda x : np.array(x[0]) , train_data)))
y_train = np.array(list(map(lambda x : x[1] , train_data)))

# %%
import gc
del train_data
gc.collect()
# Out:
# 290

# %%
import matplotlib.pyplot as plt

# %%
from torch.utils.data import DataLoader,TensorDataset
from torchvision import transforms
from torch import Tensor
import torch

# %%
x_train = x_train/255 - 0.5
y_train = Tensor(y_train)
x_train = Tensor(x_train)

# %%
x_train = x_train.view(-1,1,28,28)

# %%
dataset = TensorDataset(x_train,y_train)
dataloader = DataLoader(dataset,batch_size=8)

# %%
del x_train,y_train
del dataset
gc.collect()
# Out:
# 23187

# %% [markdown]
# ### Model

# %%
from torch import nn

# %%
class Net(nn.Module):
    
    def __init__(self):
        super(Net,self).__init__()
        self.seq_conv = nn.Sequential(
            nn.Conv2d(1,32,3),
            nn.ReLU(),
            nn.Conv2d(32,64,3),
            nn.ReLU()
        )
        self.seq_lin = nn.Sequential(
            nn.Linear(24*24*64,128),
            nn.ReLU(),
            nn.Linear(128,32),
            nn.ReLU(),
            nn.Linear(32,10),
            nn.Softmax(dim=1)
        )
    
    def forward(self,x):
        
        x = self.seq_conv(x)
        x_shape = x.shape
        x = x.view(-1,x_shape[1]*x_shape[2]*x_shape[3])
        x = self.seq_lin(x)
        return x

# %%
sample_input = Tensor(np.ndarray(2*28*28).reshape(2,1,28,28))

# %%
net = Net()

# %%
from torchsummary import summary
summary(net,input_size=(1,28,28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 26, 26]             320
#               ReLU-2           [-1, 32, 26, 26]               0
#             Conv2d-3           [-1, 64, 24, 24]          18,496
#               ReLU-4           [-1, 64, 24, 24]               0
#             Linear-5                  [-1, 128]       4,718,720
#               ReLU-6                  [-1, 128]               0
#             Linear-7                   [-1, 32]           4,128
#               ReLU-8                   [-1, 32]               0
#             Linear-9                   [-1, 10]             330
#           Softmax-10                   [-1, 10]               0
# ================================================================
# Total params: 4,741,994
# Trainable params: 4,741,994
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.90
# Params size (MB): 18.09
# Estimated Total Size (MB): 18.99
# ----------------------------------------------------------------

# %% [markdown]
# ### loss function and optimizer

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters())

# %%
for x,y in dataloader:
    out = net(x)
    loss = loss_fn(out,y.long())
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
# Out:
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4627, grad_fn=<NllLossBackward>)
# tensor(1.4616, grad_fn=<NllLossBackward>)
# tensor(1.4773, grad_fn=<NllLossBackward>)
# tensor(1.5382, grad_fn=<NllLossBackward>)
# tensor(1.4618, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7105, grad_fn=<NllLossBackward>)
# tensor(1.4620, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5858, grad_fn=<NllLossBackward>)
# tensor(1.5487, grad_fn=<NllLossBackward>)
# tensor(1.5826, grad_fn=<NllLossBackward>)
# tensor(1.7097, grad_fn=<NllLossBackward>)
# tensor(1.6088, grad_fn=<NllLossBackward>)
# tensor(1.5921, grad_fn=<NllLossBackward>)
# tensor(1.8315, grad_fn=<NllLossBackward>)
# tensor(1.5076, grad_fn=<NllLossBackward>)
# tensor(1.9570, grad_fn=<NllLossBackward>)
# tensor(1.4619, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4991, grad_fn=<NllLossBackward>)
# tensor(1.8299, grad_fn=<NllLossBackward>)
# tensor(1.5864, grad_fn=<NllLossBackward>)
# tensor(1.6113, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4674, grad_fn=<NllLossBackward>)
# tensor(1.5864, grad_fn=<NllLossBackward>)
# tensor(1.5817, grad_fn=<NllLossBackward>)
# tensor(1.7206, grad_fn=<NllLossBackward>)
# tensor(1.8203, grad_fn=<NllLossBackward>)
# tensor(1.4635, grad_fn=<NllLossBackward>)
# tensor(1.8324, grad_fn=<NllLossBackward>)
# tensor(1.8351, grad_fn=<NllLossBackward>)
# tensor(1.5812, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5866, grad_fn=<NllLossBackward>)
# tensor(1.6402, grad_fn=<NllLossBackward>)
# tensor(1.4622, grad_fn=<NllLossBackward>)
# tensor(1.5911, grad_fn=<NllLossBackward>)
# tensor(1.7166, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.8368, grad_fn=<NllLossBackward>)
# tensor(1.6818, grad_fn=<NllLossBackward>)
# tensor(1.7411, grad_fn=<NllLossBackward>)
# tensor(1.7130, grad_fn=<NllLossBackward>)
# tensor(1.7095, grad_fn=<NllLossBackward>)
# tensor(1.4945, grad_fn=<NllLossBackward>)
# tensor(1.7041, grad_fn=<NllLossBackward>)
# tensor(1.4844, grad_fn=<NllLossBackward>)
# tensor(1.7386, grad_fn=<NllLossBackward>)
# tensor(1.5390, grad_fn=<NllLossBackward>)
# tensor(1.4647, grad_fn=<NllLossBackward>)
# tensor(1.7067, grad_fn=<NllLossBackward>)
# tensor(1.7107, grad_fn=<NllLossBackward>)
# tensor(1.7072, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.5912, grad_fn=<NllLossBackward>)
# tensor(1.9525, grad_fn=<NllLossBackward>)
# tensor(1.7099, grad_fn=<NllLossBackward>)
# tensor(1.5801, grad_fn=<NllLossBackward>)
# tensor(1.8296, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7189, grad_fn=<NllLossBackward>)
# tensor(1.5886, grad_fn=<NllLossBackward>)
# tensor(1.8448, grad_fn=<NllLossBackward>)
# tensor(1.5894, grad_fn=<NllLossBackward>)
# tensor(1.8361, grad_fn=<NllLossBackward>)
# tensor(1.8349, grad_fn=<NllLossBackward>)
# tensor(1.7276, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.6555, grad_fn=<NllLossBackward>)
# tensor(1.9563, grad_fn=<NllLossBackward>)
# tensor(1.5855, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.9554, grad_fn=<NllLossBackward>)
# tensor(1.5224, grad_fn=<NllLossBackward>)
# tensor(1.5850, grad_fn=<NllLossBackward>)
# tensor(1.8389, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5889, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.6672, grad_fn=<NllLossBackward>)
# tensor(1.5865, grad_fn=<NllLossBackward>)
# tensor(1.4657, grad_fn=<NllLossBackward>)
# tensor(1.7069, grad_fn=<NllLossBackward>)
# tensor(1.8335, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5804, grad_fn=<NllLossBackward>)
# tensor(1.7459, grad_fn=<NllLossBackward>)
# tensor(1.7090, grad_fn=<NllLossBackward>)
# tensor(1.4613, grad_fn=<NllLossBackward>)
# tensor(1.8353, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.6388, grad_fn=<NllLossBackward>)
# tensor(1.7118, grad_fn=<NllLossBackward>)
# tensor(1.5860, grad_fn=<NllLossBackward>)
# tensor(1.8324, grad_fn=<NllLossBackward>)
# tensor(1.4613, grad_fn=<NllLossBackward>)
# tensor(1.7798, grad_fn=<NllLossBackward>)
# tensor(1.5822, grad_fn=<NllLossBackward>)
# tensor(1.7057, grad_fn=<NllLossBackward>)
# tensor(1.5935, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5740, grad_fn=<NllLossBackward>)
# tensor(1.7112, grad_fn=<NllLossBackward>)
# tensor(2.0802, grad_fn=<NllLossBackward>)
# tensor(1.6013, grad_fn=<NllLossBackward>)
# tensor(1.4888, grad_fn=<NllLossBackward>)
# tensor(1.9346, grad_fn=<NllLossBackward>)
# tensor(1.5706, grad_fn=<NllLossBackward>)
# tensor(1.7064, grad_fn=<NllLossBackward>)
# tensor(1.4658, grad_fn=<NllLossBackward>)
# tensor(1.4677, grad_fn=<NllLossBackward>)
# tensor(1.7017, grad_fn=<NllLossBackward>)
# tensor(1.7111, grad_fn=<NllLossBackward>)
# tensor(1.4635, grad_fn=<NllLossBackward>)
# tensor(1.8361, grad_fn=<NllLossBackward>)
# tensor(1.4781, grad_fn=<NllLossBackward>)
# tensor(1.7112, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5900, grad_fn=<NllLossBackward>)
# tensor(1.6290, grad_fn=<NllLossBackward>)
# tensor(1.7127, grad_fn=<NllLossBackward>)
# tensor(1.7076, grad_fn=<NllLossBackward>)
# tensor(1.7068, grad_fn=<NllLossBackward>)
# tensor(1.6905, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7091, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.6299, grad_fn=<NllLossBackward>)
# tensor(1.5947, grad_fn=<NllLossBackward>)
# tensor(1.5095, grad_fn=<NllLossBackward>)
# tensor(1.6604, grad_fn=<NllLossBackward>)
# tensor(1.7067, grad_fn=<NllLossBackward>)
# tensor(1.5896, grad_fn=<NllLossBackward>)
# tensor(1.9213, grad_fn=<NllLossBackward>)
# tensor(1.8360, grad_fn=<NllLossBackward>)
# tensor(1.5820, grad_fn=<NllLossBackward>)
# tensor(1.5384, grad_fn=<NllLossBackward>)
# tensor(1.5845, grad_fn=<NllLossBackward>)
# tensor(1.4622, grad_fn=<NllLossBackward>)
# tensor(1.5739, grad_fn=<NllLossBackward>)
# tensor(1.7112, grad_fn=<NllLossBackward>)
# tensor(1.5643, grad_fn=<NllLossBackward>)
# tensor(1.7103, grad_fn=<NllLossBackward>)
# tensor(1.8329, grad_fn=<NllLossBackward>)
# tensor(1.9498, grad_fn=<NllLossBackward>)
# tensor(1.4619, grad_fn=<NllLossBackward>)
# tensor(1.6226, grad_fn=<NllLossBackward>)
# tensor(2.0481, grad_fn=<NllLossBackward>)
# tensor(1.8330, grad_fn=<NllLossBackward>)
# tensor(1.8215, grad_fn=<NllLossBackward>)
# tensor(1.8300, grad_fn=<NllLossBackward>)
# tensor(1.5864, grad_fn=<NllLossBackward>)
# tensor(1.7111, grad_fn=<NllLossBackward>)
# tensor(1.4651, grad_fn=<NllLossBackward>)
# tensor(1.8362, grad_fn=<NllLossBackward>)
# tensor(1.4672, grad_fn=<NllLossBackward>)
# tensor(1.4618, grad_fn=<NllLossBackward>)
# tensor(1.5585, grad_fn=<NllLossBackward>)
# tensor(1.7060, grad_fn=<NllLossBackward>)
# tensor(1.9592, grad_fn=<NllLossBackward>)
# tensor(1.4630, grad_fn=<NllLossBackward>)
# tensor(1.7104, grad_fn=<NllLossBackward>)
# tensor(1.4732, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.5865, grad_fn=<NllLossBackward>)
# tensor(1.4975, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.8976, grad_fn=<NllLossBackward>)
# tensor(1.4765, grad_fn=<NllLossBackward>)
# tensor(1.6905, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7111, grad_fn=<NllLossBackward>)
# tensor(1.5822, grad_fn=<NllLossBackward>)
# tensor(1.7088, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5329, grad_fn=<NllLossBackward>)
# tensor(1.7185, grad_fn=<NllLossBackward>)
# tensor(1.5841, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4641, grad_fn=<NllLossBackward>)
# tensor(1.8338, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.8919, grad_fn=<NllLossBackward>)
# tensor(1.5866, grad_fn=<NllLossBackward>)
# tensor(1.5863, grad_fn=<NllLossBackward>)
# tensor(1.5852, grad_fn=<NllLossBackward>)
# tensor(1.9558, grad_fn=<NllLossBackward>)
# tensor(1.8349, grad_fn=<NllLossBackward>)
# tensor(1.9568, grad_fn=<NllLossBackward>)
# tensor(1.7080, grad_fn=<NllLossBackward>)
# tensor(1.5905, grad_fn=<NllLossBackward>)
# tensor(1.4984, grad_fn=<NllLossBackward>)
# tensor(1.4814, grad_fn=<NllLossBackward>)
# tensor(1.7143, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.4625, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5109, grad_fn=<NllLossBackward>)
# tensor(1.5913, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.7101, grad_fn=<NllLossBackward>)
# tensor(1.8347, grad_fn=<NllLossBackward>)
# tensor(1.8276, grad_fn=<NllLossBackward>)
# tensor(1.5887, grad_fn=<NllLossBackward>)
# tensor(1.5857, grad_fn=<NllLossBackward>)
# tensor(1.5857, grad_fn=<NllLossBackward>)
# tensor(1.7095, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4624, grad_fn=<NllLossBackward>)
# tensor(1.7103, grad_fn=<NllLossBackward>)
# tensor(1.4620, grad_fn=<NllLossBackward>)
# tensor(1.9597, grad_fn=<NllLossBackward>)
# tensor(1.4669, grad_fn=<NllLossBackward>)
# tensor(1.7111, grad_fn=<NllLossBackward>)
# tensor(1.5841, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5848, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.8288, grad_fn=<NllLossBackward>)
# tensor(1.7000, grad_fn=<NllLossBackward>)
# tensor(1.5854, grad_fn=<NllLossBackward>)
# tensor(1.5873, grad_fn=<NllLossBackward>)
# tensor(1.8033, grad_fn=<NllLossBackward>)
# tensor(1.5859, grad_fn=<NllLossBackward>)
# tensor(1.5755, grad_fn=<NllLossBackward>)
# tensor(1.7081, grad_fn=<NllLossBackward>)
# tensor(1.5940, grad_fn=<NllLossBackward>)
# tensor(1.5855, grad_fn=<NllLossBackward>)
# tensor(1.7129, grad_fn=<NllLossBackward>)
# tensor(1.4646, grad_fn=<NllLossBackward>)
# tensor(1.7647, grad_fn=<NllLossBackward>)
# tensor(1.5598, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7104, grad_fn=<NllLossBackward>)
# tensor(1.5859, grad_fn=<NllLossBackward>)
# tensor(1.7121, grad_fn=<NllLossBackward>)
# tensor(1.7110, grad_fn=<NllLossBackward>)
# tensor(1.7108, grad_fn=<NllLossBackward>)
# tensor(1.4628, grad_fn=<NllLossBackward>)
# tensor(1.5864, grad_fn=<NllLossBackward>)
# tensor(1.4643, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.4692, grad_fn=<NllLossBackward>)
# tensor(1.5871, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7104, grad_fn=<NllLossBackward>)
# tensor(1.7014, grad_fn=<NllLossBackward>)
# tensor(1.8351, grad_fn=<NllLossBackward>)
# tensor(1.5845, grad_fn=<NllLossBackward>)
# tensor(1.7112, grad_fn=<NllLossBackward>)
# tensor(1.4616, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5870, grad_fn=<NllLossBackward>)
# tensor(1.8319, grad_fn=<NllLossBackward>)
# tensor(1.8339, grad_fn=<NllLossBackward>)
# tensor(1.7063, grad_fn=<NllLossBackward>)
# tensor(1.6642, grad_fn=<NllLossBackward>)
# tensor(1.7112, grad_fn=<NllLossBackward>)
# tensor(1.5808, grad_fn=<NllLossBackward>)
# tensor(1.7037, grad_fn=<NllLossBackward>)
# tensor(1.5837, grad_fn=<NllLossBackward>)
# tensor(1.7061, grad_fn=<NllLossBackward>)
# tensor(1.7123, grad_fn=<NllLossBackward>)
# tensor(1.8348, grad_fn=<NllLossBackward>)
# tensor(1.8224, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.8663, grad_fn=<NllLossBackward>)
# tensor(1.7108, grad_fn=<NllLossBackward>)
# tensor(1.7073, grad_fn=<NllLossBackward>)
# tensor(1.6811, grad_fn=<NllLossBackward>)
# tensor(1.5877, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.5107, grad_fn=<NllLossBackward>)
# tensor(1.7102, grad_fn=<NllLossBackward>)
# tensor(1.5866, grad_fn=<NllLossBackward>)
# tensor(1.4811, grad_fn=<NllLossBackward>)
# tensor(1.7346, grad_fn=<NllLossBackward>)
# tensor(1.8297, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5841, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5830, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.5896, grad_fn=<NllLossBackward>)
# tensor(1.8142, grad_fn=<NllLossBackward>)
# tensor(1.7356, grad_fn=<NllLossBackward>)
# tensor(1.7100, grad_fn=<NllLossBackward>)
# tensor(1.7330, grad_fn=<NllLossBackward>)
# tensor(1.6847, grad_fn=<NllLossBackward>)
# tensor(1.7104, grad_fn=<NllLossBackward>)
# tensor(1.8289, grad_fn=<NllLossBackward>)
# tensor(1.7104, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4723, grad_fn=<NllLossBackward>)
# tensor(1.5835, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.7071, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5843, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5873, grad_fn=<NllLossBackward>)
# tensor(1.5859, grad_fn=<NllLossBackward>)
# tensor(1.5170, grad_fn=<NllLossBackward>)
# tensor(1.7313, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.8264, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.7104, grad_fn=<NllLossBackward>)
# tensor(1.5864, grad_fn=<NllLossBackward>)
# tensor(1.5821, grad_fn=<NllLossBackward>)
# tensor(1.6773, grad_fn=<NllLossBackward>)
# tensor(1.7116, grad_fn=<NllLossBackward>)
# tensor(1.7072, grad_fn=<NllLossBackward>)
# tensor(1.5835, grad_fn=<NllLossBackward>)
# tensor(1.5113, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.5883, grad_fn=<NllLossBackward>)
# tensor(1.8664, grad_fn=<NllLossBackward>)
# tensor(1.6474, grad_fn=<NllLossBackward>)
# tensor(1.5877, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.4620, grad_fn=<NllLossBackward>)
# tensor(1.7198, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5860, grad_fn=<NllLossBackward>)
# tensor(1.7101, grad_fn=<NllLossBackward>)
# tensor(1.8030, grad_fn=<NllLossBackward>)
# tensor(1.7413, grad_fn=<NllLossBackward>)
# tensor(1.8376, grad_fn=<NllLossBackward>)
# tensor(1.7112, grad_fn=<NllLossBackward>)
# tensor(1.7104, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.9573, grad_fn=<NllLossBackward>)
# tensor(1.5864, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.8317, grad_fn=<NllLossBackward>)
# tensor(1.6646, grad_fn=<NllLossBackward>)
# tensor(1.4629, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.4645, grad_fn=<NllLossBackward>)
# tensor(1.8327, grad_fn=<NllLossBackward>)
# tensor(2.0807, grad_fn=<NllLossBackward>)
# tensor(1.5866, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5857, grad_fn=<NllLossBackward>)
# tensor(1.7112, grad_fn=<NllLossBackward>)
# tensor(1.7111, grad_fn=<NllLossBackward>)
# tensor(1.5859, grad_fn=<NllLossBackward>)
# tensor(1.7946, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.4617, grad_fn=<NllLossBackward>)
# tensor(1.5874, grad_fn=<NllLossBackward>)
# tensor(1.5811, grad_fn=<NllLossBackward>)
# tensor(1.5816, grad_fn=<NllLossBackward>)
# tensor(1.7105, grad_fn=<NllLossBackward>)
# tensor(1.6057, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.6523, grad_fn=<NllLossBackward>)
# tensor(1.5839, grad_fn=<NllLossBackward>)
# tensor(1.8338, grad_fn=<NllLossBackward>)
# tensor(1.6826, grad_fn=<NllLossBackward>)
# tensor(1.5869, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7115, grad_fn=<NllLossBackward>)
# tensor(1.8302, grad_fn=<NllLossBackward>)
# tensor(1.7070, grad_fn=<NllLossBackward>)
# tensor(1.4894, grad_fn=<NllLossBackward>)
# tensor(1.7113, grad_fn=<NllLossBackward>)
# tensor(1.7123, grad_fn=<NllLossBackward>)
# tensor(1.4613, grad_fn=<NllLossBackward>)
# tensor(1.8340, grad_fn=<NllLossBackward>)
# tensor(1.7116, grad_fn=<NllLossBackward>)
# tensor(1.7080, grad_fn=<NllLossBackward>)
# tensor(1.5884, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.8352, grad_fn=<NllLossBackward>)
# tensor(1.8337, grad_fn=<NllLossBackward>)
# tensor(1.6426, grad_fn=<NllLossBackward>)
# tensor(1.5863, grad_fn=<NllLossBackward>)
# tensor(1.7034, grad_fn=<NllLossBackward>)
# tensor(1.7123, grad_fn=<NllLossBackward>)
# tensor(1.8332, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7145, grad_fn=<NllLossBackward>)
# tensor(1.7159, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.8356, grad_fn=<NllLossBackward>)
# tensor(1.5934, grad_fn=<NllLossBackward>)
# tensor(1.5816, grad_fn=<NllLossBackward>)
# tensor(1.6934, grad_fn=<NllLossBackward>)
# tensor(1.6138, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.4614, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.8312, grad_fn=<NllLossBackward>)
# tensor(1.7077, grad_fn=<NllLossBackward>)
# tensor(1.7277, grad_fn=<NllLossBackward>)
# tensor(1.7053, grad_fn=<NllLossBackward>)
# tensor(1.6957, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5815, grad_fn=<NllLossBackward>)
# tensor(1.7051, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5864, grad_fn=<NllLossBackward>)
# tensor(1.5731, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.5776, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.6917, grad_fn=<NllLossBackward>)
# tensor(1.5157, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5830, grad_fn=<NllLossBackward>)
# tensor(1.7112, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5850, grad_fn=<NllLossBackward>)
# tensor(1.8317, grad_fn=<NllLossBackward>)
# tensor(1.8364, grad_fn=<NllLossBackward>)
# tensor(1.7073, grad_fn=<NllLossBackward>)
# tensor(1.7075, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.8882, grad_fn=<NllLossBackward>)
# tensor(1.8058, grad_fn=<NllLossBackward>)
# tensor(1.7089, grad_fn=<NllLossBackward>)
# tensor(1.5866, grad_fn=<NllLossBackward>)
# tensor(1.7079, grad_fn=<NllLossBackward>)
# tensor(1.5814, grad_fn=<NllLossBackward>)
# tensor(1.7094, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.8341, grad_fn=<NllLossBackward>)
# tensor(1.7076, grad_fn=<NllLossBackward>)
# tensor(1.5826, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.5895, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.4937, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5474, grad_fn=<NllLossBackward>)
# tensor(1.9583, grad_fn=<NllLossBackward>)
# tensor(1.5863, grad_fn=<NllLossBackward>)
# tensor(1.5853, grad_fn=<NllLossBackward>)
# tensor(1.6732, grad_fn=<NllLossBackward>)
# tensor(1.6329, grad_fn=<NllLossBackward>)
# tensor(1.5815, grad_fn=<NllLossBackward>)
# tensor(1.5863, grad_fn=<NllLossBackward>)
# tensor(1.6726, grad_fn=<NllLossBackward>)
# tensor(1.7108, grad_fn=<NllLossBackward>)
# tensor(1.9580, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.8298, grad_fn=<NllLossBackward>)
# tensor(1.7111, grad_fn=<NllLossBackward>)
# tensor(1.8293, grad_fn=<NllLossBackward>)
# tensor(1.8354, grad_fn=<NllLossBackward>)
# tensor(1.6061, grad_fn=<NllLossBackward>)
# tensor(1.8320, grad_fn=<NllLossBackward>)
# tensor(1.5985, grad_fn=<NllLossBackward>)
# tensor(1.7107, grad_fn=<NllLossBackward>)
# tensor(1.4623, grad_fn=<NllLossBackward>)
# tensor(1.8310, grad_fn=<NllLossBackward>)
# tensor(1.5860, grad_fn=<NllLossBackward>)
# tensor(1.8324, grad_fn=<NllLossBackward>)
# tensor(1.5885, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7070, grad_fn=<NllLossBackward>)
# tensor(1.4613, grad_fn=<NllLossBackward>)
# tensor(1.5916, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.5816, grad_fn=<NllLossBackward>)
# tensor(1.7074, grad_fn=<NllLossBackward>)
# tensor(1.5860, grad_fn=<NllLossBackward>)
# tensor(1.5908, grad_fn=<NllLossBackward>)
# tensor(1.6075, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.8290, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.6988, grad_fn=<NllLossBackward>)
# tensor(1.7029, grad_fn=<NllLossBackward>)
# tensor(1.7104, grad_fn=<NllLossBackward>)
# tensor(1.4616, grad_fn=<NllLossBackward>)
# tensor(1.4623, grad_fn=<NllLossBackward>)
# tensor(1.7075, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7111, grad_fn=<NllLossBackward>)
# tensor(1.7111, grad_fn=<NllLossBackward>)
# tensor(1.7108, grad_fn=<NllLossBackward>)
# tensor(1.5809, grad_fn=<NllLossBackward>)
# tensor(1.6800, grad_fn=<NllLossBackward>)
# tensor(1.5831, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.8302, grad_fn=<NllLossBackward>)
# tensor(1.9555, grad_fn=<NllLossBackward>)
# tensor(1.4614, grad_fn=<NllLossBackward>)
# tensor(1.9616, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.5817, grad_fn=<NllLossBackward>)
# tensor(1.4614, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.8359, grad_fn=<NllLossBackward>)
# tensor(1.7114, grad_fn=<NllLossBackward>)
# tensor(1.8256, grad_fn=<NllLossBackward>)
# tensor(1.8440, grad_fn=<NllLossBackward>)
# tensor(1.5922, grad_fn=<NllLossBackward>)
# tensor(1.5856, grad_fn=<NllLossBackward>)
# tensor(1.8360, grad_fn=<NllLossBackward>)
# tensor(1.5240, grad_fn=<NllLossBackward>)
# tensor(1.7111, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5840, grad_fn=<NllLossBackward>)
# tensor(1.7111, grad_fn=<NllLossBackward>)
# tensor(1.4617, grad_fn=<NllLossBackward>)
# tensor(1.7009, grad_fn=<NllLossBackward>)
# tensor(1.5925, grad_fn=<NllLossBackward>)
# tensor(1.5036, grad_fn=<NllLossBackward>)
# tensor(1.4628, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5860, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7062, grad_fn=<NllLossBackward>)
# tensor(1.8633, grad_fn=<NllLossBackward>)
# tensor(1.9439, grad_fn=<NllLossBackward>)
# tensor(1.7055, grad_fn=<NllLossBackward>)
# tensor(1.7109, grad_fn=<NllLossBackward>)
# tensor(1.5843, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.5835, grad_fn=<NllLossBackward>)
# tensor(1.5866, grad_fn=<NllLossBackward>)
# tensor(1.7206, grad_fn=<NllLossBackward>)
# tensor(1.4639, grad_fn=<NllLossBackward>)
# tensor(1.9456, grad_fn=<NllLossBackward>)
# tensor(1.4615, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.6954, grad_fn=<NllLossBackward>)
# tensor(1.8361, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.8368, grad_fn=<NllLossBackward>)
# tensor(1.5886, grad_fn=<NllLossBackward>)
# tensor(1.7113, grad_fn=<NllLossBackward>)
# tensor(1.5802, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7003, grad_fn=<NllLossBackward>)
# tensor(1.6734, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5931, grad_fn=<NllLossBackward>)
# tensor(1.7097, grad_fn=<NllLossBackward>)
# tensor(1.4613, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7111, grad_fn=<NllLossBackward>)
# tensor(1.8361, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.7109, grad_fn=<NllLossBackward>)
# tensor(1.7111, grad_fn=<NllLossBackward>)
# tensor(1.5855, grad_fn=<NllLossBackward>)
# tensor(1.5831, grad_fn=<NllLossBackward>)
# tensor(1.6875, grad_fn=<NllLossBackward>)
# tensor(1.7106, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.6559, grad_fn=<NllLossBackward>)
# tensor(1.4615, grad_fn=<NllLossBackward>)
# tensor(1.5855, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7092, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(2.0828, grad_fn=<NllLossBackward>)
# tensor(1.9586, grad_fn=<NllLossBackward>)
# tensor(1.7040, grad_fn=<NllLossBackward>)
# tensor(1.5887, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5823, grad_fn=<NllLossBackward>)
# tensor(1.7010, grad_fn=<NllLossBackward>)
# tensor(1.7082, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.4636, grad_fn=<NllLossBackward>)
# tensor(1.9570, grad_fn=<NllLossBackward>)
# tensor(1.8355, grad_fn=<NllLossBackward>)
# tensor(1.8510, grad_fn=<NllLossBackward>)
# tensor(1.5838, grad_fn=<NllLossBackward>)
# tensor(1.8300, grad_fn=<NllLossBackward>)
# tensor(1.7112, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.8325, grad_fn=<NllLossBackward>)
# tensor(1.5374, grad_fn=<NllLossBackward>)
# tensor(1.7064, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4617, grad_fn=<NllLossBackward>)
# tensor(1.5460, grad_fn=<NllLossBackward>)
# tensor(1.5860, grad_fn=<NllLossBackward>)
# tensor(1.5018, grad_fn=<NllLossBackward>)
# tensor(1.6088, grad_fn=<NllLossBackward>)
# tensor(1.6979, grad_fn=<NllLossBackward>)
# tensor(1.5871, grad_fn=<NllLossBackward>)
# tensor(1.7111, grad_fn=<NllLossBackward>)
# tensor(1.5874, grad_fn=<NllLossBackward>)
# tensor(1.7110, grad_fn=<NllLossBackward>)
# tensor(1.7068, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5857, grad_fn=<NllLossBackward>)
# tensor(1.5847, grad_fn=<NllLossBackward>)
# tensor(1.5817, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.6231, grad_fn=<NllLossBackward>)
# tensor(1.7100, grad_fn=<NllLossBackward>)
# tensor(1.7111, grad_fn=<NllLossBackward>)
# tensor(1.8349, grad_fn=<NllLossBackward>)
# tensor(1.7062, grad_fn=<NllLossBackward>)
# tensor(1.4630, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5847, grad_fn=<NllLossBackward>)
# tensor(1.4616, grad_fn=<NllLossBackward>)
# tensor(1.5829, grad_fn=<NllLossBackward>)
# tensor(1.8359, grad_fn=<NllLossBackward>)
# tensor(1.4674, grad_fn=<NllLossBackward>)
# tensor(1.7111, grad_fn=<NllLossBackward>)
# tensor(1.5899, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.7108, grad_fn=<NllLossBackward>)
# tensor(1.7346, grad_fn=<NllLossBackward>)
# tensor(1.7568, grad_fn=<NllLossBackward>)
# tensor(1.5819, grad_fn=<NllLossBackward>)
# tensor(1.5866, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7066, grad_fn=<NllLossBackward>)
# tensor(1.7100, grad_fn=<NllLossBackward>)
# tensor(1.4650, grad_fn=<NllLossBackward>)
# tensor(1.4613, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5261, grad_fn=<NllLossBackward>)
# tensor(1.5825, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5837, grad_fn=<NllLossBackward>)
# tensor(1.7111, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4684, grad_fn=<NllLossBackward>)
# tensor(1.5867, grad_fn=<NllLossBackward>)
# tensor(1.5831, grad_fn=<NllLossBackward>)
# tensor(1.5865, grad_fn=<NllLossBackward>)
# tensor(1.5867, grad_fn=<NllLossBackward>)
# tensor(1.4882, grad_fn=<NllLossBackward>)
# tensor(1.8366, grad_fn=<NllLossBackward>)
# tensor(1.5838, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.5857, grad_fn=<NllLossBackward>)
# tensor(1.8326, grad_fn=<NllLossBackward>)
# tensor(1.7104, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.8326, grad_fn=<NllLossBackward>)
# tensor(1.5848, grad_fn=<NllLossBackward>)
# tensor(1.6678, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.9603, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.4617, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.7068, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.8190, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.7094, grad_fn=<NllLossBackward>)
# tensor(1.5400, grad_fn=<NllLossBackward>)
# tensor(1.7110, grad_fn=<NllLossBackward>)
# tensor(1.5865, grad_fn=<NllLossBackward>)
# tensor(1.7620, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7055, grad_fn=<NllLossBackward>)
# tensor(1.7111, grad_fn=<NllLossBackward>)
# tensor(1.7127, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7149, grad_fn=<NllLossBackward>)
# tensor(1.5821, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.5859, grad_fn=<NllLossBackward>)
# tensor(1.4613, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.8137, grad_fn=<NllLossBackward>)
# tensor(1.7078, grad_fn=<NllLossBackward>)
# tensor(1.7106, grad_fn=<NllLossBackward>)
# tensor(1.5232, grad_fn=<NllLossBackward>)
# tensor(1.5851, grad_fn=<NllLossBackward>)
# tensor(1.7108, grad_fn=<NllLossBackward>)
# tensor(1.7109, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.7022, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7112, grad_fn=<NllLossBackward>)
# tensor(1.9611, grad_fn=<NllLossBackward>)
# tensor(1.7117, grad_fn=<NllLossBackward>)
# tensor(1.7121, grad_fn=<NllLossBackward>)
# tensor(1.7109, grad_fn=<NllLossBackward>)
# tensor(1.7114, grad_fn=<NllLossBackward>)
# tensor(1.8326, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.5766, grad_fn=<NllLossBackward>)
# tensor(1.9611, grad_fn=<NllLossBackward>)
# tensor(1.6754, grad_fn=<NllLossBackward>)
# tensor(1.4617, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.6412, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.5917, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.8360, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.7143, grad_fn=<NllLossBackward>)
# tensor(1.5863, grad_fn=<NllLossBackward>)
# tensor(1.6374, grad_fn=<NllLossBackward>)
# tensor(1.6674, grad_fn=<NllLossBackward>)
# tensor(1.6891, grad_fn=<NllLossBackward>)
# tensor(1.4700, grad_fn=<NllLossBackward>)
# tensor(1.5621, grad_fn=<NllLossBackward>)
# tensor(1.5487, grad_fn=<NllLossBackward>)
# tensor(1.5902, grad_fn=<NllLossBackward>)
# tensor(1.5882, grad_fn=<NllLossBackward>)
# tensor(1.4622, grad_fn=<NllLossBackward>)
# tensor(1.7102, grad_fn=<NllLossBackward>)
# tensor(1.7104, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5853, grad_fn=<NllLossBackward>)
# tensor(1.7103, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4665, grad_fn=<NllLossBackward>)
# tensor(1.5998, grad_fn=<NllLossBackward>)
# tensor(1.8356, grad_fn=<NllLossBackward>)
# tensor(1.6952, grad_fn=<NllLossBackward>)
# tensor(1.8313, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5873, grad_fn=<NllLossBackward>)
# tensor(1.4634, grad_fn=<NllLossBackward>)
# tensor(1.4625, grad_fn=<NllLossBackward>)
# tensor(1.5722, grad_fn=<NllLossBackward>)
# tensor(1.4937, grad_fn=<NllLossBackward>)
# tensor(1.4857, grad_fn=<NllLossBackward>)
# tensor(1.5710, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.6513, grad_fn=<NllLossBackward>)
# tensor(1.6554, grad_fn=<NllLossBackward>)
# tensor(1.4655, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4841, grad_fn=<NllLossBackward>)
# tensor(1.4613, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5818, grad_fn=<NllLossBackward>)
# tensor(1.4626, grad_fn=<NllLossBackward>)
# tensor(1.5881, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.6864, grad_fn=<NllLossBackward>)
# tensor(1.7093, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4617, grad_fn=<NllLossBackward>)
# tensor(1.4614, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4872, grad_fn=<NllLossBackward>)
# tensor(1.4651, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5437, grad_fn=<NllLossBackward>)
# tensor(1.4870, grad_fn=<NllLossBackward>)
# tensor(1.4881, grad_fn=<NllLossBackward>)
# tensor(1.4656, grad_fn=<NllLossBackward>)
# tensor(1.4617, grad_fn=<NllLossBackward>)
# tensor(1.4654, grad_fn=<NllLossBackward>)
# tensor(1.4621, grad_fn=<NllLossBackward>)
# tensor(1.6048, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5872, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4614, grad_fn=<NllLossBackward>)
# tensor(1.4719, grad_fn=<NllLossBackward>)
# tensor(1.7111, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.6638, grad_fn=<NllLossBackward>)
# tensor(1.5836, grad_fn=<NllLossBackward>)
# tensor(1.7970, grad_fn=<NllLossBackward>)
# tensor(1.5297, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.6916, grad_fn=<NllLossBackward>)
# tensor(1.5925, grad_fn=<NllLossBackward>)
# tensor(1.4726, grad_fn=<NllLossBackward>)
# tensor(1.5637, grad_fn=<NllLossBackward>)
# tensor(1.7533, grad_fn=<NllLossBackward>)
# tensor(1.4627, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5650, grad_fn=<NllLossBackward>)
# tensor(1.5863, grad_fn=<NllLossBackward>)
# tensor(1.5818, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5051, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7082, grad_fn=<NllLossBackward>)
# tensor(1.5854, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.5859, grad_fn=<NllLossBackward>)
# tensor(1.4613, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.6341, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.5860, grad_fn=<NllLossBackward>)
# tensor(1.5711, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4614, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.5324, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4616, grad_fn=<NllLossBackward>)
# tensor(1.5866, grad_fn=<NllLossBackward>)
# tensor(1.4618, grad_fn=<NllLossBackward>)
# tensor(1.6060, grad_fn=<NllLossBackward>)
# tensor(1.7111, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5399, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4617, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5790, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4785, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4616, grad_fn=<NllLossBackward>)
# tensor(1.4705, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4626, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5685, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5482, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4629, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4614, grad_fn=<NllLossBackward>)
# tensor(1.4632, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.6155, grad_fn=<NllLossBackward>)
# tensor(1.5860, grad_fn=<NllLossBackward>)
# tensor(1.5870, grad_fn=<NllLossBackward>)
# tensor(1.6772, grad_fn=<NllLossBackward>)
# tensor(1.6468, grad_fn=<NllLossBackward>)
# tensor(1.6120, grad_fn=<NllLossBackward>)
# tensor(1.4615, grad_fn=<NllLossBackward>)
# tensor(1.4661, grad_fn=<NllLossBackward>)
# tensor(1.5432, grad_fn=<NllLossBackward>)
# tensor(1.5963, grad_fn=<NllLossBackward>)
# tensor(1.4624, grad_fn=<NllLossBackward>)
# tensor(1.4986, grad_fn=<NllLossBackward>)
# tensor(1.4615, grad_fn=<NllLossBackward>)
# tensor(1.4613, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7016, grad_fn=<NllLossBackward>)
# tensor(1.5117, grad_fn=<NllLossBackward>)
# tensor(1.4815, grad_fn=<NllLossBackward>)
# tensor(1.7106, grad_fn=<NllLossBackward>)
# tensor(1.4613, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5733, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5197, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.8356, grad_fn=<NllLossBackward>)
# tensor(1.4616, grad_fn=<NllLossBackward>)
# tensor(1.5775, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5744, grad_fn=<NllLossBackward>)
# tensor(1.4748, grad_fn=<NllLossBackward>)
# tensor(1.7131, grad_fn=<NllLossBackward>)
# tensor(1.4621, grad_fn=<NllLossBackward>)
# tensor(1.4812, grad_fn=<NllLossBackward>)
# tensor(1.4617, grad_fn=<NllLossBackward>)
# tensor(1.4688, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4840, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4617, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4666, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4618, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7071, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4621, grad_fn=<NllLossBackward>)
# tensor(1.5096, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5858, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.5699, grad_fn=<NllLossBackward>)
# tensor(1.4719, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5860, grad_fn=<NllLossBackward>)
# tensor(1.7112, grad_fn=<NllLossBackward>)
# tensor(1.5854, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5792, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7111, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5921, grad_fn=<NllLossBackward>)
# tensor(1.4701, grad_fn=<NllLossBackward>)
# tensor(1.5280, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5750, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.5829, grad_fn=<NllLossBackward>)
# tensor(1.4721, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4629, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.6056, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4643, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.8347, grad_fn=<NllLossBackward>)
# tensor(1.5198, grad_fn=<NllLossBackward>)
# tensor(1.4620, grad_fn=<NllLossBackward>)
# tensor(1.4656, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5798, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.6448, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5855, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4742, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5341, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7186, grad_fn=<NllLossBackward>)
# tensor(1.4660, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.4620, grad_fn=<NllLossBackward>)
# tensor(1.5372, grad_fn=<NllLossBackward>)
# tensor(1.7102, grad_fn=<NllLossBackward>)
# tensor(1.4614, grad_fn=<NllLossBackward>)
# tensor(1.5415, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.5817, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4616, grad_fn=<NllLossBackward>)
# tensor(1.4669, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.6406, grad_fn=<NllLossBackward>)
# tensor(1.4617, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.4619, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7206, grad_fn=<NllLossBackward>)
# tensor(1.4613, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.6923, grad_fn=<NllLossBackward>)
# tensor(1.4625, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4735, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4613, grad_fn=<NllLossBackward>)
# tensor(1.5822, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4625, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4615, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4614, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5531, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4645, grad_fn=<NllLossBackward>)
# tensor(1.5865, grad_fn=<NllLossBackward>)
# tensor(1.4627, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5824, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5841, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.6761, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4963, grad_fn=<NllLossBackward>)
# tensor(1.4711, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4615, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.8929, grad_fn=<NllLossBackward>)
# tensor(1.5867, grad_fn=<NllLossBackward>)
# tensor(1.5746, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.6662, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5096, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4643, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.6847, grad_fn=<NllLossBackward>)
# tensor(1.5812, grad_fn=<NllLossBackward>)
# tensor(1.4632, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7733, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4616, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4644, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5851, grad_fn=<NllLossBackward>)
# tensor(1.4621, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5819, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.5841, grad_fn=<NllLossBackward>)
# tensor(1.6596, grad_fn=<NllLossBackward>)
# tensor(1.4698, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5104, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.6019, grad_fn=<NllLossBackward>)
# tensor(1.5772, grad_fn=<NllLossBackward>)
# tensor(1.5812, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7111, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5825, grad_fn=<NllLossBackward>)
# tensor(1.4628, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.5225, grad_fn=<NllLossBackward>)
# tensor(1.4709, grad_fn=<NllLossBackward>)
# tensor(1.8235, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.5394, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.5845, grad_fn=<NllLossBackward>)
# tensor(1.5490, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4631, grad_fn=<NllLossBackward>)
# tensor(1.4637, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.5666, grad_fn=<NllLossBackward>)
# tensor(1.6090, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7010, grad_fn=<NllLossBackward>)
# tensor(1.4628, grad_fn=<NllLossBackward>)
# tensor(1.4613, grad_fn=<NllLossBackward>)
# tensor(1.8361, grad_fn=<NllLossBackward>)
# tensor(1.5826, grad_fn=<NllLossBackward>)
# tensor(1.4613, grad_fn=<NllLossBackward>)
# tensor(1.4637, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5937, grad_fn=<NllLossBackward>)
# tensor(1.5884, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7070, grad_fn=<NllLossBackward>)
# tensor(1.5861, grad_fn=<NllLossBackward>)
# tensor(1.7068, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.6895, grad_fn=<NllLossBackward>)
# tensor(1.6003, grad_fn=<NllLossBackward>)
# tensor(1.6228, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.7133, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4621, grad_fn=<NllLossBackward>)
# tensor(1.6258, grad_fn=<NllLossBackward>)
# tensor(1.5859, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.5862, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)
# tensor(1.4612, grad_fn=<NllLossBackward>)

# %%
from IPython.display import clear_output

# %%
epochs = 2
for epoch in range(epochs):
    loss_t = 0
    accuracy = 0
    for inx,(x,y) in enumerate(dataloader):
        
        if(inx%100==0):
            clear_output()
            print('epoch {} : {} / {}'.format(epoch+1,inx,len(dataloader)))
        out = net(x)
        if(not all(np.argmax(out.detach().numpy(),axis=1)==y.numpy())):
            accuracy+=sum((np.argmax(out.detach().numpy(),axis=1) == y.numpy()))
        loss = loss_fn(out,y.long())
        loss_t+=loss.item()
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        
    loss_t/=len(dataloader)
    print(loss_t)
    input()
# Out:
# epoch 2 : 1200 / 1250
# 1.5009912710189819
